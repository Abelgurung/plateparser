# %%
import pandas as pd

import sys
sys.path.append('../src')

from plateParser import plateParser

# %%
sample_df = pd.read_excel('../examples/Example_data.xlsx')
sample_df.head(20)
# Out:
#        OD700  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0   mScarlet         NaN         NaN         NaN         NaN         NaN
# 1        45s         NaN         NaN         NaN         NaN         NaN
# 2         <>    1.000000    2.000000    3.000000     4.00000     5.00000
# 3          A    0.037747    0.037335    0.037746     0.68178     0.46685
# 4          B    0.037335    0.037678    0.037530     0.35869     0.32659
# 5          C    0.830640    0.551470    0.517870     0.36485     0.32876
# 6          D    0.567020    0.413450    0.320540     0.36867     0.30867
# 7          E    0.853850    0.525590    0.386980     0.34796     0.35349
# 8          F    0.601960    0.782300    0.427880     0.32298     0.31901
# 9          G    0.422730    0.775820    0.713860     0.38848     0.35205
# 10         H    0.292750    0.286710    0.280470     0.30442     0.29233
# 11        0s         NaN         NaN         NaN         NaN         NaN
# ...

# %%
parsed_df = plateParser.plateFormat(sample_df, keep_index=True, save= 'sample_plate.csv')
parsed_df
# Out:
# Plate size recognized: 8 x 12
#   0         1         2         3        4        5        6        7   \
# 0  A  0.037747  0.037335  0.037746  0.68178  0.46685  0.33461  0.28588
# 1  B  0.037335  0.037678   0.03753  0.35869  0.32659  0.33229  0.30903
# 2  C   0.83064   0.55147   0.51787  0.36485  0.32876  0.35074  0.33846
# 3  D   0.56702   0.41345   0.32054  0.36867  0.30867  0.34161  0.34427
# 4  E   0.85385   0.52559   0.38698  0.34796  0.35349  0.34476  0.37661
# 5  F   0.60196    0.7823   0.42788  0.32298  0.31901  0.31261  0.33727
# 6  G   0.42273   0.77582   0.71386  0.38848  0.35205  0.35586  0.35365
# 7  H   0.29275   0.28671   0.28047  0.30442  0.29233  0.36964  0.70579
#
#         8        9        10       11       12
# 0  0.45419  0.44534   0.4453  0.68907  0.34224
# 1  0.31958  0.31678  0.40677  0.68993  0.70439
# 2  0.33051  0.35798  0.33188  0.31482  0.85514
# 3  0.35697  0.34753  0.31834  0.37805  0.89334
# 4  0.41196  0.36678  0.35891  0.43649   0.4078
# ...

# %%
parsed_df = plateParser.plateFormat(sample_df, keep_index=False)
parsed_df = parsed_df.astype(float)
# Out:
# Plate size recognized: 8 x 12

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(parsed_df, annot=True, cmap="coolwarm")

plt.show()
